# %% [markdown]
# # Scraping jumia products under flash sales

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
from urllib.parse import urljoin

# %%
url = 'https://www.jumia.co.ke/flash-sales/' 
links = []

# Extracting links from both pages

while True:
    links.append(url)
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    next_page = soup.find('a',{'class':'pg', 'aria-label':'Next Page'})
    if next_page:
        next_url = next_page.get('href')
        url = urljoin(url,next_url)
    else:
        break

# Checking if the links from 2 pages have been added to the list
print(links)

details_list = []

# Scraping data from the 2 pages
for url in links:
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    details = soup.find_all('div', class_ = 'info')
    footers  = soup.find_all('footer', class_ = 'ft')
    
    for detail,footer in zip(details,footers):
        name = detail.find('h3', class_ = 'name').text.strip()
        price =  detail.find('div', class_ = 'prc').text.strip()
        try:
            old_price = detail.find('div', class_ = 'old').text.strip()
        except:
            old_price = " "
        try:
            discount = detail.find('div', class_ = 'bdg _dsct _sm').text.strip()
        except:
            discount = " "
        try:
            stars_reviews = detail.find('div', class_ = 'rev').text.strip()
        except:
            stars_reviews = " "
    
        try:
            items_left = footer.find('div', class_ = 'stk').text.strip()
        except:
            items_left = " Out of stock"
            
            
    
        details_dict = {'Name':name,'price':price,'Old Price':old_price,'discount':discount,'Stars and Reviews':stars_reviews,'Items Left':items_left}
        details_list.append(details_dict)
        
flash_sale_data = pd.DataFrame(details_list)
flash_sale_data
# Out:
# ['https://www.jumia.co.ke/flash-sales/', 'https://www.jumia.co.ke/flash-sales/?page=2#catalog-listing']
#                                                  Name       price   Old Price  \
# 0                Qwen Memory Card 64Gb High Speed C10     KSh 800
# 1    Oraimo Slice Link 10000mAh 12W Power Bank_ Black   KSh 1,530   KSh 2,000
# 2   Qwen Portable Laptop Holder Aluminum Alloy Fol...   KSh 1,000
# 3   RichRipple 6A 120w Super Fast Charge 3in1 USB ...     KSh 299     KSh 419
# 4   Nice One 6PCS 370ML High Quality Porcelain Tea...     KSh 599     KSh 899
# 5   Oraimo Traveller 4 20000mAh 2.1A Triple Ports ...   KSh 2,299   KSh 3,500
# 6        LASA Double Sided Nano Removal Tape Gel Grip     KSh 350     KSh 660
# 7   RichRipple Pro2+ Bluetooth Headsets Wireless P...     KSh 599     KSh 754
# 8       Garnier Even & Matte Vitamin C Cleansing Foam     KSh 579     KSh 825
# 9   Garnier Even & Matte Vitamin  C Micellar Clean...     KSh 403     KSh 775
# 10             Power King 4 Way Extension Power Cable     KSh 550     KSh 599
# 11           Garnier Even & Matte Dark Spot Corrector     KSh 542   KSh 1,090
# 12  NIVEA MEN Deep Antibacterial Anti-Perspirant R...     KSh 659   KSh 1,040
# 43           Kenyan Originals KO Classic Can ? 200ml.      KSh 99     KSh 127
# 44   Kenyan Originals KO Rose & Cucumber Can ? 200ml.      KSh 99     KSh 127
# 45                 Ramtons RA/101-2.1CH 75W Subwoofer  KSh 12,039  KSh 12,995
# 46     Ramtons Rw/154- 7kg Front Load Washing Machine  KSh 56,430  KSh 60,900
#
#    discount   Stars and Reviews      Items Left
# 0               4.1 out of 5(7)   38 items left
# 1       24%       5 out of 5(1)   35 items left
# 2              4.5 out of 5(43)  176 items left
# 3       29%    3.7 out of 5(62)  255 items left
# 4       33%    4.2 out of 5(11)    9 items left
# 5       34%    4.3 out of 5(97)   18 items left
# 6       47%    4.6 out of 5(10)  158 items left
# 7       21%   4.1 out of 5(208)  442 items left
# 8       30%  4.4 out of 5(2427)  386 items left
# 9       48%  4.4 out of 5(1233)   73 items left
# 10       8%    4.2 out of 5(54)  482 items left
# 11      50%    4 out of 5(2988)  345 items left
# 12      37%  4.5 out of 5(1255)   53 items left
# 13      30%  4.5 out of 5(1300)  458 items left
# 14      23%  4.4 out of 5(5316)  399 items left
# 15      43%    4.3 out of 5(18)  179 items left
# 16      30%   4.5 out of 5(410)  127 items left
# 17      41%     4.5 out of 5(6)   19 items left
# 18      32%  4.7 out of 5(1362)   75 items left
# 19       9%    4.8 out of 5(45)    Out of stock
# 20      15%  4.2 out of 5(2195)  402 items left
# 21       9%   4.4 out of 5(656)    Out of stock
# 22      31%       5 out of 5(1)    6 items left
# 23      20%       4 out of 5(1)  186 items left
# 24      40%  4.3 out of 5(4537)  190 items left
# 25      32%  4.5 out of 5(1565)  397 items left
# 26      37%   4.2 out of 5(147)    2 items left
# 27      41%  4.3 out of 5(3356)  391 items left
# 28                                 Out of stock
# 29      25%    4.4 out of 5(65)   14 items left
# 30      31%                        3 items left
# 31      31%                       10 items left
# 32      31%                       23 items left
# 33      35%    4.4 out of 5(76)   16 items left
# 34      11%   4.4 out of 5(506)    Out of stock
# 35      16%       5 out of 5(1)   29 items left
# 36      36%   4.6 out of 5(873)  329 items left
# 37      16%       4 out of 5(2)   25 items left
# 38      12%     3.3 out of 5(3)   45 items left
# 39      41%   4.4 out of 5(433)  106 items left
# 40      17%    4.5 out of 5(11)   14 items left
# 41      16%     2.5 out of 5(2)    5 items left
# 42      67%                         1 item left
# 43      22%                       25 items left
# 44      22%                       93 items left
# 45       7%                        5 items left
# 46       7%                        2 items left

# %%
# Saving to a csv file
flash_sale_data.to_csv('Flash_Sale_Data.csv',index =  False)
